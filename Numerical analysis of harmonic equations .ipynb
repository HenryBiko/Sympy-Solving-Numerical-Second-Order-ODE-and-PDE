# %%
#importing necessary packages
from sympy.interactive import printing 
printing.init_printing(use_latex=True)
from sympy import * 
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1  **(a)**

# %% [markdown]
# Here we find the general solution for for second order linear differencial equation that is homogeneous with constant coefficents
# <br>
# <br>
# in class we solved y'' +y=0 and we realized that y can take two forms either exponetial 'e^kx'or sin
# <br>
# <br>
# This is because when we plag either to the equation and solve then we end up with 0 as expected
# <br>
# <br>
# so we expect our solution-general solution- to be in the form of:
# <br>
# <br>
# y=Asin()+Bsin() where A and B are coeffcients or
# <br>
# <br>
# y=Ae^ωk+Be^ωk
# <br>
# <br>
# Either of the above forms is correct

# %%
#espressing ω,t as symbols that we will use later where omega where ω=sqrt(k/m)
ω,t=sp.symbols(' ω t')
#expressing x as a fuction
x=sp.Function('x')

# %%
#here our fuction is dependant on t 
diff_2=Eq(sp.Derivative(x(t), t, 2) + ω**2 * x(t),0)
#displaying our fuction
display(diff_2)
# Out:
#             2
#  2         d
# ω ⋅x(t) + ───(x(t)) = 0
#             2
#           dt

# %% [markdown]
# The General solution is as below where **C1** and **C2**  are coeffcients

# %%
# here we dislove the fuction which means we differenciate with respect to t , solving the equation gives us the general solution
#C1 and C2 on the display are place holders 
ans= sp.dsolve(sp.Derivative(x(t), t, 2) + ω**2 * x(t))
print("\n General solution\n" )
display(ans)
# Out:
#  General solution
#            -ⅈ⋅t⋅ω       ⅈ⋅t⋅ω
# x(t) = C₁⋅ℯ       + C₂⋅ℯ

# %% [markdown]
# **-------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# We solve for our two unkowns c1 and c2
# <br>
# We also substitute relevant variables with intial condition values where
# <br>
# ω0 = 2,
# <br>
# x(0) =1,
# <br>
# x'(0) = 0

# %%
initial_con = [sp.Eq(ans.args[1].subs(t, 0), 1), sp.Eq(ans.args[1].diff(t).subs(t, 0), 0)]
initial_con
# Out:
# [C₁ + C₂ = 1, -ⅈ⋅C₁⋅ω + ⅈ⋅C₂⋅ω = 0]

# %%
initial_con_ans_1=sp.solve(initial_con)
initial_con_ans_1
# Out:
# [{C₁: 1/2, C₂: 1/2}]

# %% [markdown]
# The below equation is as a result of solving for the cieffcients and substitutin with there values:
# <br>
# <br>
# we then simplified the equation to obtain a simpler version of x(t)
# <br>
# <br>
# The complex exponentials are not a surprise as we expected an oscillatory fuction from the natural behaviour of springs # **statistical Mechanic NS162**

# %%
initial_con_full_ans = ans.subs(initial_con_ans_1[0])
initial_con_full_ans
# Out:
#         ⅈ⋅t⋅ω    -ⅈ⋅t⋅ω
#        ℯ        ℯ
# x(t) = ────── + ───────
#          2         2

# %% [markdown]
# We substitute the values
# <br>
# <br>
# ω0 = 2,
# <br>
# <br>
# x(0) =1,
# <br>
# <br>
# x'(0) = 0
# <br>
# <br>
# Given in the problem and simplify to obtaing the below fuction

# %%
 ẋ, x_0=sp.symbols(' ẋ  x_0')
given_scenario = sp.simplify(initial_con_full_ans.subs({x_0:1, ẋ:0, ω:2}))
given_scenario
# Out:
# x(t) = cos(2⋅t)

# %% [markdown]
# We then plot the simplified **x(t)** over range

# %%
sp.plot(given_scenario.rhs)

# %% [markdown]
# The plot above follows the naturla behaviour of harmonic oscillators
# <br>
# <br>
# **--------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# # Q1 **(b)**

# %% [markdown]
# Here we implement ous solution using the **complexification technique**
# <br>
# <br>
# That is :
# u=(x+yi)^n where yi is the imaginary part and x is the real part

# %%
ω_1=sp.symbols('ω_1')

# %%
diff_1=Eq(sp.Derivative(x(t), t, 2) + ω**2 * x(t),cos(ω_1*t))
display(diff_1)
# Out:
#             2
#  2         d
# ω ⋅x(t) + ───(x(t)) = cos(t⋅ω₁)
#             2
#           dt

# %% [markdown]
# We already know the genral solution from part a here we just need to include the real part

# %%
complification=dsolve(Eq(sp.Derivative(x(t), t, 2) + ω**2 * x(t),cos(ω_1*t)))
print("\n General solution\n" )
display(complification)
# Out:
#  General solution
#            -ⅈ⋅t⋅ω       ⅈ⋅t⋅ω   cos(t⋅ω₁)
# x(t) = C₁⋅ℯ       + C₂⋅ℯ      + ─────────
#                                   2     2
#                                  ω  - ω₁

# %% [markdown]
# We solve for our two unkowns c1 and c2
# <br>
# We also substitute relevant variables with intial condition values where
# <br>
# ω0 = 2,
# <br>
# x(0) =1,
# <br>
# x'(0) = 0

# %%
complification_sol= [sp.Eq(complification.args[1].subs(t, 0), 1), sp.Eq(complification.args[1].diff(t).subs(t, 0), 0)]
display(complification_sol)
# Out:
# ⎡             1                              ⎤
# ⎢C₁ + C₂ + ──────── = 1, -ⅈ⋅C₁⋅ω + ⅈ⋅C₂⋅ω = 0⎥
# ⎢           2     2                          ⎥
# ⎣          ω  - ω₁                           ⎦

# %% [markdown]
# We substitute the values
# <br>
# <br>
# ω0 = 2,
# <br>
# <br>
# x(0) =1,
# <br>
# <br>
# x'(0) = 0
# <br>
# <br>
# Given in the problem and simplify to obtaing the below fuction

# %%
complification_sol_1=sp.solve(complification_sol)
display(complification_sol_1)
# Out:
# ⎡⎧         2     2                  2     2       ⎫⎤
# ⎢⎪        ω  - ω₁  - 1             ω  - ω₁  - 1   ⎪⎥
# ⎢⎨C₁: ───────────────────, C₂: ───────────────────⎬⎥
# ⎢⎪    2⋅(ω - ω₁)⋅(ω + ω₁)      2⋅(ω - ω₁)⋅(ω + ω₁)⎪⎥
# ⎣⎩                                                ⎭⎦

# %% [markdown]
# The below equation is as a result of solving for the cieffcients and substitutin with there values:
# <br>
# <br>
# we then simplified the equation to obtain a simpler version of x(t)
# <br>
# <br>
# The complex exponentials are not a surprise as we expected an oscillatory fuction from the natural behaviour of springs # **statistical Mechanic NS162**

# %%
complification_sol_full = ans.subs(complification_sol_1[0])
display(complification_sol_full )
# Out:
#        ⎛ 2     2    ⎞  ⅈ⋅t⋅ω   ⎛ 2     2    ⎞  -ⅈ⋅t⋅ω
#        ⎝ω  - ω₁  - 1⎠⋅ℯ        ⎝ω  - ω₁  - 1⎠⋅ℯ
# x(t) = ───────────────────── + ──────────────────────
#         2⋅(ω - ω₁)⋅(ω + ω₁)     2⋅(ω - ω₁)⋅(ω + ω₁)

# %% [markdown]
# ω1=! ω0 because the fuction will be undefined, the denominator will be 0 and this we can not solve the problem

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------**
# <br>
# <br>
# We substitute the values
# <br>
# <br>
# ω0 = 2,
# <br>
# <br>
# x(0) =1,
# <br>
# <br>
# x'(0) = 0
# <br>
# <br>
# Given in the problem and simplify to obtaing the below fuction

# %%
given_scenario_2 = sp.simplify(complification_sol_full.subs({x_0:1, ẋ:0, ω:2,ω_1:3}))
given_scenario_2
# Out:
#        6⋅cos(2⋅t)
# x(t) = ──────────
#            5

# %% [markdown]
# # Q1 **(c)**

# %% [markdown]
# We then plot the simplified **x(t)** over range

# %%
sp.plot(given_scenario_2.rhs)

# %% [markdown]
# The plot above follows the naturla behaviour of harmonic oscillators
# <br>
# <br>
# **--------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# # We repeat Q1 b and c using sin instead, all fuctions are the same just replace cos with sin, and the expanantions are same too.

# %%
diff_1_sin=Eq(sp.Derivative(x(t), t, 2) + ω**2 * x(t),sin(ω_1*t))
display(diff_1_sin)
# Out:
#             2
#  2         d
# ω ⋅x(t) + ───(x(t)) = sin(t⋅ω₁)
#             2
#           dt

# %%
complification_sin=dsolve(Eq(sp.Derivative(x(t), t, 2) + ω**2 * x(t),sin(ω_1*t)))
display(complification_sin)
# Out:
#            -ⅈ⋅t⋅ω       ⅈ⋅t⋅ω   sin(t⋅ω₁)
# x(t) = C₁⋅ℯ       + C₂⋅ℯ      + ─────────
#                                   2     2
#                                  ω  - ω₁

# %%
complification_sol_sin= [sp.Eq(complification_sin.args[1].subs(t, 0), 1), sp.Eq(complification_sin.args[1].diff(t).subs(t, 0), 0)]
display(complification_sol_sin)
# Out:
# ⎡                                   ω₁       ⎤
# ⎢C₁ + C₂ = 1, -ⅈ⋅C₁⋅ω + ⅈ⋅C₂⋅ω + ──────── = 0⎥
# ⎢                                 2     2    ⎥
# ⎣                                ω  - ω₁     ⎦

# %%
complification_sol_1_sin=sp.solve(complification_sol_sin)
display(complification_sol_1_sin)
# Out:
# ⎡⎧     3       2              3       2       ⎫⎤
# ⎢⎪    ω  - ω⋅ω₁  - ⅈ⋅ω₁      ω  - ω⋅ω₁  + ⅈ⋅ω₁⎪⎥
# ⎢⎨C₁: ─────────────────, C₂: ─────────────────⎬⎥
# ⎢⎪          ⎛ 2     2⎞             ⎛ 2     2⎞ ⎪⎥
# ⎣⎩      2⋅ω⋅⎝ω  - ω₁ ⎠         2⋅ω⋅⎝ω  - ω₁ ⎠ ⎭⎦

# %%
complification_sol_full_sin = ans.subs(complification_sol_1_sin[0])
display(complification_sol_full_sin )
# Out:
#        ⎛ 3       2       ⎞  -ⅈ⋅t⋅ω   ⎛ 3       2       ⎞  ⅈ⋅t⋅ω
#        ⎝ω  - ω⋅ω₁  - ⅈ⋅ω₁⎠⋅ℯ         ⎝ω  - ω⋅ω₁  + ⅈ⋅ω₁⎠⋅ℯ
# x(t) = ─────────────────────────── + ──────────────────────────
#                   ⎛ 2     2⎞                   ⎛ 2     2⎞
#               2⋅ω⋅⎝ω  - ω₁ ⎠               2⋅ω⋅⎝ω  - ω₁ ⎠

# %%
given_scenario_2_sin = sp.simplify(complification_sol_full_sin.subs({x_0:1, ẋ:0, ω:2,ω_1:3}))
given_scenario_2_sin
# Out:
#        ⎛            4⋅ⅈ⋅t           ⎞  -2⋅ⅈ⋅t
#        ⎝(10 - 3⋅ⅈ)⋅ℯ      + 10 + 3⋅ⅈ⎠⋅ℯ
# x(t) = ──────────────────────────────────────
#                          20

# %%
sin_plot=sp.plot(given_scenario_2_sin.rhs)
sin_plot

# %% [markdown]
# # Q1 **(d)**

# %% [markdown]
# we set x=f(t)e^(iωt): we do this because solving it directly leads to undefined solution as we get 0 at the denominator

# %% [markdown]
# x=f(t)e^(iωt)
# <br>
# <br>
# x'=f'(t)e^(iωt)+iωtf'(t)e^(iωt)
# <br>
# <br>
# x''=f''(t)e^(iωt)+iωtf'(t)e^(iωt)+iωtf'(t)e^(iωt)-ω^2 * f(t)e^(iωt)
# <br>
# <br>
# x''+ω^2*x=f"(t)e^(iωt)+2iωf'(t)e^(iωt)-ω^2 * f(t)e^(iωt)+ω^2 * f(t)e^(iωt)
# <br>
# <br>
# The last terms disapear
# <br>
# <br>
# f"(t)e^(iωt)+2iω* f(t)e^(iωt)
# <br>
# <br>
# dislvoing the fuction further yields
# e^iω
# <br>
# <br>
# e^iω=cosω+isinω
# <br>
# <br>
# general solution
# <br>
# <br>
# e^iω or cosω+isinω

# %%
import cmath
import math
from math import e
i =1j

# %%
#set x=f(t)e^(iωt)
x=sp.Function('f')(t)*e**(i*ω*t)
display(x)

# %%
fuc=Eq(sp.Derivative(x, t, 2) + ω**2 * x,sin(ω*t))
display(fuc)
# Out:
#                                       2
#                 1.0⋅ⅈ⋅t⋅ω  2         ∂ ⎛                1.0⋅ⅈ⋅t⋅ω     ⎞
# 2.71828182845905         ⋅ω ⋅f(t) + ───⎝2.71828182845905         ⋅f(t)⎠ = sin(
#                                       2
#                                     ∂t
#
#
#
# t⋅ω)

# %%
complification_ii=dsolve(Eq(sp.Derivative(x, t, 2) + ω**2 * x,sin(ω*t)))
display(complification_ii)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-38249cab242d> in <module>
# ----> 1 complification_ii=dsolve(Eq(sp.Derivative(x, t, 2) + ω**2 * x,sin(ω*t)))
#       2 display(complification_ii)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     677             # The key 'hint' stores the hint needed to be solved for.
#     678             hint = hints['hint']
# --> 679             return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#     680
#     681 def _helper_simplify(eq, hint, match, simplify=True, ics=None, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     702         # attempt to solve for func, and apply any other hint specific
#     703         # simplifications
# --> 704         sols = solvefunc(eq, func, order, match)
#     705         if isinstance(sols, Expr):
#     706             rv =  odesimp(eq, sols, func, hint)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in ode_nth_order_reducible(eq, func, order, match)
#    4552     fsol = []
#    4553     for gsoli in gsol:
# -> 4554         fsoli = dsolve(gsoli.subs(g(x), w), f(x))  # or do integration n times
#    4555         fsol.append(fsoli)
#    4556
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     644         hints = _desolve(eq, func=func,
#     645             hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
# --> 646             x0=x0, n=n, **kwargs)
#     647         eq = hints.pop('eq', eq)
#     648         all_ = hints.pop('all', False)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/deutils.py in _desolve(eq, func, hint, ics, simplify, **kwargs)
#     211     if kwargs.get('classify', True):
#     212         hints = classifier(eq, func, dict=True, ics=ics, xi=xi, eta=eta,
# --> 213         n=terms, x0=x0, prep=prep)
#     214
#     215     else:
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in classify_ode(eq, func, dict, ics, **kwargs)
#    1064     # integrals e.g.:
#    1065     # d^3/dx^3(x y) = F(x)
# -> 1066     r = _nth_algebraic_match(eq_orig, func)
#    1067     if r['solutions']:
#    1068         matching_hints['nth_algebraic'] = r
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/ode.py in _nth_algebraic_match(eq, func)
#    4621         # _t instead of fx in them and would otherwise factor
#    4622         # as t_*Integral(1, x)
# -> 4623         solns = solve(subs_eqn, func, simplify=False)
#    4624     except NotImplementedError:
#    4625         solns = []
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1172     ###########################################################################
#    1173     if bare_f:
# -> 1174         solution = _solve(f[0], *symbols, **flags)
#    1175     else:
#    1176         solution = _solve_system(f, symbols, **flags)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1763     if check:
#    1764         # keep only results if the check is not False
# -> 1765         result = [r for r in result if
#    1766                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1767     return result
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1764         # keep only results if the check is not False
#    1765         result = [r for r in result if
# -> 1766                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1767     return result
#    1768
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     303             # start over without the failed expanded form, possibly
#     304             # with a simplified solution
# --> 305             val = simplify(f.subs(sol))
#     306             if flags.get('force', True):
#     307                 val, reps = posify(val)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     578             x, handled),
#     579         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
# --> 580         simultaneous=False)
#     581     if not isinstance(expr, handled):
#     582         return done(expr)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in replace(self, query, value, map, simultaneous, exact)
#    1537             return expr
#    1538
# -> 1539         rv = bottom_up(self, rec_replace, atoms=True)
#    1540
#    1541         # restore original expressions for Dummy symbols
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in rec_replace(expr)
#    1518             result = _query(expr)
#    1519             if result or result == {}:
# -> 1520                 new = _value(expr, result)
#    1521                 if new is not None and new != expr:
#    1522                     mapping[expr] = new
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in <lambda>(expr, result)
#    1502
#    1503             if callable(value):
# -> 1504                 _value = lambda expr, result: value(expr)
#    1505             else:
#    1506                 raise TypeError(
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <lambda>(x)
#     577         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     578             x, handled),
# --> 579         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     580         simultaneous=False)
#     581     if not isinstance(expr, handled):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#     577         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     578             x, handled),
# --> 579         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     580         simultaneous=False)
#     581     if not isinstance(expr, handled):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     620         expr = piecewise_fold(expr)
#     621         # Apply doit, if doit=True
# --> 622         expr = done(expr)
#     623         # Still a Piecewise?
#     624         if expr.has(Piecewise):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in done(e)
#     539
#     540     def done(e):
# --> 541         rv = e.doit() if doit else e
#     542         return shorter(rv, collect_abs(rv))
#     543
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in doit(self, **hints)
#     311             if hints.get('deep', True):
#     312                 if isinstance(e, Basic):
# --> 313                     newe = e.doit(**hints)
#     314                     if newe != self:
#     315                         e = newe
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in doit(self, **hints)
#    1689         if hints.get('deep', True):
#    1690             terms = [term.doit(**hints) if isinstance(term, Basic) else term
# -> 1691                                          for term in self.args]
#    1692             return self.func(*terms)
#    1693         else:
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in <listcomp>(.0)
#    1689         if hints.get('deep', True):
#    1690             terms = [term.doit(**hints) if isinstance(term, Basic) else term
# -> 1691                                          for term in self.args]
#    1692             return self.func(*terms)
#    1693         else:
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     574                 else:
#     575                     antideriv = self._eval_integral(
# --> 576                         function, xab[0], **eval_kwargs)
#     577                     if antideriv is None and meijerg is True:
#     578                         ret = try_meijerg(function, xab)
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#    1030                     try:
#    1031                         if conds == 'piecewise':
# -> 1032                             h = heurisch_wrapper(g, x, hints=[])
#    1033                         else:
#    1034                             h = heurisch_(g, x, hints=[])
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     134
#     135     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
# --> 136                    unnecessary_permutations, _try_heurisch)
#     137     if not isinstance(res, Basic):
#     138         return res
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     721             solution = _integrate()
#     722     else:
# --> 723         solution = _integrate()
#     724
#     725     if solution is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     695
#     696         try:
# --> 697             find_non_syms(raw_numer)
#     698         except PolynomialError:
#     699             return None
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
# --> 690                 list(map(find_non_syms, expr.args))
#     691             else:
#     692                 # TODO: Non-polynomial expression. This should have been
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/integrals/heurisch.py in find_non_syms(expr)
#     685             elif expr in syms:
#     686                 pass # ignore variables
# --> 687             elif not expr.has(*syms):
#     688                 non_syms.add(expr)
#     689             elif expr.is_Add or expr.is_Mul or expr.is_Pow:
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in has(self, *patterns)
#    1262
#    1263         """
# -> 1264         return any(self._has(pattern) for pattern in patterns)
#    1265
#    1266     def _has(self, pattern):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in <genexpr>(.0)
#    1262
#    1263         """
# -> 1264         return any(self._has(pattern) for pattern in patterns)
#    1265
#    1266     def _has(self, pattern):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in _has(self, pattern)
#    1279         if _has_matcher is not None:
#    1280             match = _has_matcher()
# -> 1281             return any(match(arg) for arg in preorder_traversal(self))
#    1282         else:
#    1283             return any(arg == pattern for arg in preorder_traversal(self))
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in <genexpr>(.0)
#    1279         if _has_matcher is not None:
#    1280             match = _has_matcher()
# -> 1281             return any(match(arg) for arg in preorder_traversal(self))
#    1282         else:
#    1283             return any(arg == pattern for arg in preorder_traversal(self))
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/basic.py in <lambda>(other)
#    1285     def _has_matcher(self):
#    1286         """Helper for .has()"""
# -> 1287         return lambda other: self == other
#    1288
#    1289     def replace(self, query, value, map=False, simultaneous=True, exact=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/expr.py in __eq__(self, other)
#     131                 type(self) != type(other)):
#     132             return False
# --> 133         a, b = self._hashable_content(), other._hashable_content()
#     134         if a != b:
#     135             return False
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/symbol.py in _hashable_content(self)
#     379
#     380     def _hashable_content(self):
# --> 381         return Symbol._hashable_content(self) + (self.dummy_index,)
#     382
#     383
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/symbol.py in _hashable_content(self)
#     272     def _hashable_content(self):
#     273         # Note: user-specified assumptions not hashed, just derived ones
# --> 274         return (self.name,) + tuple(sorted(self.assumptions0.items()))
#     275
#     276     def _eval_subs(self, old, new):
#
# /opt/anaconda3/lib/python3.7/site-packages/sympy/core/symbol.py in assumptions0(self)
#     282     def assumptions0(self):
#     283         return dict((key, value) for key, value
# --> 284                 in self._assumptions.items() if value is not None)
#     285
#     286     @cacheit
#
# KeyboardInterrupt:

# %% [markdown]
# # Q1 **(e)**

# %% [markdown]
# The general solution differ in the coefficients as well as the placement of the imaginary part
# <br>
# <br>
# in the first one we had general solution in the form Ae^ωk+Be^ωk while in the d part we have cosω+isinω:

# %% [markdown]
# # Q1 **(f)** Vedio explanation based on Numeroical analysis knowledge

# %% [markdown]
# We know that ω=sqrt(k/m) where k is the spring constant and m is the mass. If k is big it means the spring is strong that the oscillation will be small but faster , while if m is big the ossicilation would be slower due to change of intertia. Applying the same knowledge on the brige from the 0.21 second the oscillation are slow but big which means the mass is greater than what the spring can hold thus may tend towards breaking point . Some sections of the brige are vibrating faster but the amplitude is smaller which means the bridge has kess weight there that is less than the spring constant. The wind acts as an external agents that acts as a catalyst, here it increased m thus the bridge reached its breaking point. Notice that it breaks fast where the vibration were slow but big (m>>k).. This show how omega which is a fuction of sqrt(k/m) contributes in the harmonic oscilation

# %% [markdown]
# # Question 2

# %% [markdown]
# I recorded two audio from different location
# <br>
# <br>
# and used https://www.online-convert.com/result#j=5eaeec88-dddd-426d-a83b-4012d440a97c
#    <br>
#    <br>
# to convert the audi into wave. I then read it throw wave.open from scipy

# %%
from scipy.io import wavfile
from scipy import * 
import wave
import matplotlib.pyplot as plt

# %%
noise = wave.open("noise1.wav",'r')
noise_rate=np.inf

# %%
sig = np.frombuffer(noise.readframes(noise_rate), dtype=np.int16)
plt.plot(sig)
plt.title("one period from noise")
plt.xlabel("sample")
plt.ylabel("amplitude")
# Out:
# Text(0, 0.5, 'amplitude')

# %%
trans_1 = fft(sig)
plt.figure(figsize=(10, 6), dpi=330)
plt.plot(abs(trans_1)[:20000])
plt.ylabel("amplitude")
plt.xlabel("Hz")
plt.title("frequency decomposition with discrete fourier transform for noise 1")
plt.show()

# %%
peak_1=2500+2500/2
peak_1
# Out:
# 3750.0

# %% [markdown]
# The dominant peak is at around 3750.0HZ
# <br>
# <br>
# This is the highest frequency after we decompose the wave into finite number of sinusoidal, From the graph we other smaller peaks that reduce over time and flattens towards the 20000HZ

# %%
noise_2 = wave.open("noise2.wav",'r')
noise_rate=np.inf

# %%
sig_2 = np.frombuffer(noise_2.readframes(noise_rate), dtype=np.int16)
plt.plot(sig_2)
plt.title("one period from noise")
plt.xlabel("sample")
plt.ylabel("amplitude")
# Out:
# Text(0, 0.5, 'amplitude')

# %%
from scipy.signal import find_peaks
trans_2 = fft(sig_2)
plt.figure(figsize=(10, 6), dpi=330)
peaks, _=  find_peaks(trans_2, height=0)
plt.plot(abs(trans_2)[:40000])
plt.ylabel("amplitude")
plt.xlabel("Hz")
plt.title("frequency decomposition with discrete fourier transform for noise 2")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/signal/_peak_finding.py:264: ComplexWarning: Casting complex values to real discards the imaginary part
#   value = np.asarray(value, order='C', dtype=np.float64)

# %%
peak=7500+2500/2
peak
# Out:
# 8750.0

# %% [markdown]
# The dominat frequncy is at around 8750.0HZ
# <br>
# From there the frequency hight reduces over time and decreases more between 35000 and 40000. This means that if I was studying and got rid of 8750.0 then noise would reducee significantly . It is at the dorminat frequency where the highest energy is found E = hν = hc/λ, where E = energy, h = Planck's constant, ν = frequency, c = the speed of light, and λ = wavelength. # **statistical Mechanic NS162** . Removing the highest frequency means that noise measured in decibels would be lower

# %% [markdown]
# From the second gragh I would need earbud that cancels frequncy btn 2500Hz to 35000Hz as its the region with more fluctuation and high average enegy thus noise

# %% [markdown]
# From the 1st gragh the noise cancellation should be able to cancel frequencies between 2500Hz to 17500Hz
